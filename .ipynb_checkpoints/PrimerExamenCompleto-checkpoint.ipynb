# %% [markdown]
# # Primer Exámen Métodos Numéricos
# # 03 Mayo, 2021
# ### Alumno: Mario Rosas Otero
# ### Licenciatura en Tecnología
# ### Profesor: José Manuel Torres Valencia

# %%
# Librerías
from sympy import *
import math as m
import mpmath
import pandas as pd
import numpy as np
from MetNum import *

# %% [markdown]
# #### Ejercicio 1: Se implementa el método de Newton-Raphson para la ecuación de Redlich-Kwong
# <center> $ab = PT^{0.5}V^3-RT^{1.5}V^2-(Pb^2T^{0.5}-a+RT^{1.5}b)V$ </center>

# %%
# Creamos una función que realice el Método de Newton - Raphson para 
# la función de Redlich-Kwong ab = PT^(0.5)V^(3)-RT^(1.5)V^(2)-(Pb^(2)T^(0.5)-a+RT^(1.5)b)V

def Newton_Raphson(x_0,P,R,T,a,b): # Metemos las magnitudes que intervienen en la ecuación
    gxs = []
    results = [] 
    fin = 1
    while fin == 1:
        # Configuramos la operación iterativa que representada como x_(i+1) = f(x_i)/f'(x_i) 
        # Función -> f(x) PT^(0.5)V^(3)-RT^(1.5)V^(2)-(Pb^(2)T^(0.5)-a+RT^(1.5)b)V-ab = 0
        # Derivada dF/dV -> f'(x) = 3PT^(0.5)V^(2)-2RT^(1.5)V-(Pb^(2)T^(0.5)-a+RT^(1.5)b)
        x_0 = x_0 - ((P*(T**0.5)*x_0**3)-(R*(T**1.5)*x_0**2)-(((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b))*x_0)-a*b) / ((3*P*(T**0.5)*x_0**2)-(2*R*(T**1.5)*x_0)-((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b))) 
        # Se evalúa el valor recien calculado en la función original, para verificar la aproximación
        resu =  ((P*(T**0.5)*x_0**3)-(R*(T**1.5)*x_0**2)-(((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b))*x_0)-a*b)
        print(x_0)
        gxs.append(x_0)
        results.append(resu) 
        # Se evalúa la precisión de la aproximación para detener la ejecución.
        if -0.000000001 < resu < 0.000000001:
            fin = 0 

    allres = { 'x_i': gxs,
                'f(x)': results}

    allresdf = pd.DataFrame(allres)
    return allresdf

# %%
# Estabecemos las magnitudes generales dadas, y las específicas para el Helio

#Presión en atm
P = 50
# Temperatura en Kelvins
T = 373.15
# Temperatura crítica del Helio en Kelvins
Tc = 5.26 
#Presión crítica en atms
Pc = 2.26
# Constante ideal de los gases en (atm L)/(gmol K)
R = 0.08205
#Volumen molar inicial en L/gmol 
V = (R*T)/P
x_0 = V
# Calculamos a
a = 0.4278*((R**2*(Tc**2.5))/(Pc))
#Calculamos b
b = 0.0867*((R*Tc)/(Pc))

# Llamamos a la función para correr el métos Newton-Raphson sobre la función de Redlich-Kwong
Newton_Raphson(x_0,P,R,T,a,b)
# Out:
# 0.629688446466771
# 0.6287722156097847
# 0.6287695756313703
# 0.628769575609484
#         x_i          f(x)
# 0  0.629688  3.610827e-01
# 1  0.628772  1.034445e-03
# 2  0.628770  8.575740e-09
# 3  0.628770  3.235606e-14

# %%
# Se imprimen los valores de los coeficientes de las componentes de la función
P*(T**0.5), R*(T**1.5), ((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b)),a*b
# Out:
# (965.8545439143514, 591.4305504441515, 9.976067376294095, 0.001338840557973571)

# %%
# Se imprimen los valores de los coeficientes de las componentes de la derivada
3*P*(T**0.5), 2*R*(T**1.5), ((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b))
# Out:
# (2897.5636317430544, 1182.861100888303, 9.976067376294095)

# %%
x_inicial = (R*T)/P
X =  Symbol('X')
func = (P*(T**0.5)*X**3)-(R*(T**1.5)*X**2)-(((P*b**2*(T**0.5))-(a)+(R*(T**1.5)*b))*X)-a*b
# print(func)
MN_NR(func,x_inicial)
# Out:
# 2897.56363174305*X**2 - 1182.8611008883*X - 9.9760673762941
#                  x_i                  f(x)
# 0  0.629688446466771     0.361082723512794
# 1  0.628772215609785   0.00103444532914860
# 2  0.628769575631370   8.57576414187986e-9
# 3  0.628769575609484  2.16815424307881e-14

# %% [markdown]
# #### Ejercicio 2
#
# Para la función
#
# <center> $x^3-6x+2=0$ </center>
#
# Corremos tres depejes distintos y vemos con cual se encuentra una raíz entre [2,3].

# %% [markdown]
# ######  Con el despeje a) $x = \sqrt[3]{6x-2} $

# %%
# Elegimos un valor intermedio como nuestro valor inicial dados los parametros [2,3]
res = 2.5

fin = 1
gxs = []
results = []

while fin == 1:
   # Evaluamos el valor inicial en el depeje a)
    res = np.cbrt(6*res-2)
    # Evaluamos el valor recien calculado en la función original
    resu = res**3-6*res+2
    gxs.append(res)
    results.append(resu) 
    # Establecemos un criterio de paro del calculo, con el resultado de la evaluación 
    # del valor en la función original 
    if -0.00001 < resu < 0.00001:
        fin =0
    
allres = { 'g(x)': gxs,
           'f(x)': results}

allresdf = pd.DataFrame(allres)
allresdf
# Out:
#         g(x)      f(x)
# 0   2.351335  0.891992
# 1   2.296277  0.330347
# 2   2.275201  0.126458
# 3   2.267028  0.049034
# 4   2.263843  0.019108
# 5   2.262600  0.007461
# 6   2.262114  0.002915
# 7   2.261924  0.001140
# 8   2.261850  0.000445
# 9   2.261821  0.000174
# 10  2.261810  0.000068
# 11  2.261805  0.000027
# 12  2.261803  0.000010
# 13  2.261803  0.000004

# %%
X = Symbol('X')
func_d_a = X**3-6*X+2
desp_d_a = cbrt(6*X-2)
vi_a = 2.5
MN_PF(func_d_a,desp_d_a,vi_a)
# Out:
#                 g(x)                  f(x)
# 0   2.35133468772076     0.891991873675453
# 1   2.29627678183351     0.330347435323465
# 2   2.27520052596258     0.126457535225592
# 3   2.26702821319979    0.0490338765767606
# 4   2.26384349239824    0.0191083248093003
# 5   2.26259998854111   0.00746102314279364
# 6   2.26211407965397   0.00291545332282011
# 7   2.26192415021012   0.00113957666310578
# 8   2.26184990294299  0.000445483602793557
# 9   2.26182087685693  0.000174156516366612
# 10  2.26180952925123   6.80856341479305e-5
# 11  2.26180509292960   2.66179298018858e-5
# 12  2.26180335855463   1.04062498481616e-5
# 13  2.26180268050195   4.06831606465943e-6

# %% [markdown]
# ######  Con el despeje b) $\sqrt{6-\frac{2}{x}}$

# %%
# Elegimos un valor intermedio como nuestro valor inicial dados los parametros [2,3]
res = 2.5

fin = 1
gxs = []
results = []

while fin == 1:
    # Evaluamos el valor inicial en el depeje b)
    res = np.sqrt(6-(2/res))
    # Evaluamos el valor recien calculado en la función original
    resu = res**3-6*res+2
    gxs.append(res)
    results.append(resu) 
    # Establecemos un criterio de paro del calculo, con el resultado de la evaluación 
    # del valor en la función original 
    if -0.00001 < resu < 0.00001:
        fin =0
    
allres = { 'g(x)': gxs,
           'f(x)': results}

allresdf = pd.DataFrame(allres)
allresdf
# Out:
#        g(x)      f(x)
# 0  2.280351  0.175719
# 1  2.263392  0.014874
# 2  2.261940  0.001283
# 3  2.261814  0.000111
# 4  2.261803  0.000010

# %%
X = Symbol('X')
func_d_b = X**3-6*X+2
desp_d_b = sqrt(6-(2/X))
vi_b = 2.5
MN_PF(func_d_b,desp_d_b,vi_b)
# Out:
#                g(x)                  f(x)
# 0  2.28035085019828     0.175719319841381
# 1  2.26339169846780    0.0148741600258544
# 2  2.26193951208497   0.00128319493600149
# 3  2.26181410770467  0.000110882169598681
# 4  2.26180327045840   9.58279129448366e-6

# %% [markdown]
# ##### Con el despeje c) $x = \frac{-2}{x^2-6}$

# %%
# Elegimos un valor intermedio como nuestro valor inicial dados los parametros [2,3]
res = 2.5
fin = 1

gxs = []
results = [] 
while fin == 1:
     # Evaluamos el valor inicial en el depeje b)
    res = (-2)/(res**2-6)
    # Evaluamos el valor recien calculado en la función original
    resu = res**3-6*res+2
    gxs.append(res)
    results.append(resu) 
    # Establecemos un criterio de paro del calculo, con el resultado de la evaluación 
    # del valor en la función original
    if -0.00001 < resu < 0.00001:
        fin = 0
    
allres = { 'g(x)': gxs,
           'f(x)': results}

allresdf = pd.DataFrame(allres)
allresdf
# Out:
#        g(x)        f(x)
# 0 -8.000000 -462.000000
# 1 -0.034483    2.206856
# 2  0.333399    0.036663
# 3  0.339625    0.001423
# 4  0.339867    0.000056
# 5  0.339876    0.000002

# %%
X = Symbol('X')
func_d_b = X**3-6*X+2
desp_d_b = (-2)/(X**2-6)
vi_b = 2.5
MN_PF(func_d_b,desp_d_b,vi_b)
# Out:
#                   g(x)                 f(x)
# 0    -8.00000000000000    -462.000000000000
# 1  -0.0344827586206897     2.20685554963303
# 2    0.333399405351833   0.0366626332980029
# 3    0.339625182107012  0.00142306375820456
# 4    0.339867008318085  5.58466143708445e-5
# 5    0.339876498793966  2.19257366480648e-6

# %% [markdown]
# ##### Ejercicio 3: Implementamos el método de Newton-Raphson Mutivariable para el sistemad de ecuaciones:
#
# <center> $ln(xy)+x^2y^2=8$ </center>
# <center> $sen(x)+y\; e^x=2$ </center>

# %%
#Proponiendo valores iniciales 
x = 100
y = 100

fin = 1
xs = []
ys = []
cambiosx = []
cambiosy = []
cont = 0

while fin == 1:
    cont += 1
    
    x_anterior = x
    y_anterior = y
    
    # Función 1  ln(xy) + x^2 y^2 - 8 = 0
    f1 = m.log(x*y)+(x**2)*(y**2)-8
    #Función 2 sen(x) + y e^x - 2 = 0
    f2 = m.sin(mpmath.radians(x)) +y*m.exp(x) -2
    
    # Obtenemos la derivada df1/dx = 1/x + 2x y^2
    df1dx = (1/x)+2*x*(y**2)
    # Obtenemos la derivada df1/dy = 1/y +2y x^2
    df1dy = (1/y)+2*y*(x**2)
    # Obtenemos la derivada df2/dx = cos(x)+y e^x7
    df2dx = m.cos(mpmath.radians(x))+y*m.exp(x)
    # Obtenemos la derivada df2/dy
    df2dy = m.exp(x)
    # Creamos la Matriz Jacobiana y sacamos su inversa
    jac_inv = np.linalg.inv([[df1dx,df1dy], [df2dx,df2dy]])
    primat = Matrix(jac_inv)
    # Se multiplica (J(x,y)^-1)([[-f1],[-f2]])
    h = jac_inv.dot([-f1,-f2])
#     h = np.array([(-f1)*m_i[0,0]+(-f1)*m_i[1,0],(-f2)*m_i[0,1]+(-f2)*m_i[1,1]])
    
    # Recalculamos los valores de 'x' y 'y' 
    x += h[0]
    y += h[1]
    
    xs.append(x)
    ys.append(x)
    
    # Medimos el cambio respecto a la iteración anterior
    cambiox = x_anterior - x
    cambioy = y_anterior - y
    
    cambiosx.append(cambiox)
    cambiosy.append(cambioy)
    
    print(cont,'\t x: {0:.6f}'.format(x), ' y: {0:.6f}'.format(y) ,' cambio en x: {0:.6f}'.format(cambiox), ' cambio en y: {0:.6f}'.format(cambioy))
    
    # Si el cambio es lo suficientemente pequeño se detiene el proceso.
    if 0.0000001 < cambiox < 0.0000001 and 0.0000001 < cambioy < 0.0000001:
        fin = 0
    
# primat
# Out:
# 1 	 x: 99.494949  y: 50.505050  cambio en x: 0.505051  cambio en y: 49.494950
# 2 	 x: 98.989873  y: 25.508909  cambio en x: 0.505076  cambio en y: 24.996141
# 3 	 x: 98.484770  y: 12.884617  cambio en x: 0.505103  cambio en y: 12.624292
# 4 	 x: 97.979641  y: 6.508399  cambio en x: 0.505129  cambio en y: 6.376218
# 5 	 x: 97.474483  y: 3.287772  cambio en x: 0.505158  cambio en y: 3.220628
# 6 	 x: 96.969287  y: 1.660970  cambio en x: 0.505196  cambio en y: 1.626802
# 7 	 x: 96.464010  y: 0.839249  cambio en x: 0.505277  cambio en y: 0.821721
# 8 	 x: 95.958456  y: 0.424286  cambio en x: 0.505554  cambio en y: 0.414963
# 9 	 x: 95.451730  y: 0.214997  cambio en x: 0.506726  cambio en y: 0.209289
# 10 	 x: 94.939871  y: 0.110048  cambio en x: 0.511859  cambio en y: 0.104949
# 11 	 x: 94.406192  y: 0.058730  cambio en x: 0.533679  cambio en y: 0.051318
# 12 	 x: 93.791051  y: 0.036127  cambio en x: 0.615140  cambio en y: 0.022603
# 13 	 x: 92.978601  y: 0.029352  cambio en x: 0.812451  cambio en y: 0.006776
# 14 	 x: 91.996464  y: 0.028827  cambio en x: 0.982137  cambio en y: 0.000524
# 15 	 x: 90.986047  y: 0.029128  cambio en x: 1.010417  cambio en y: -0.000300
# 82 	 x: 22.576963  y: 0.117160  cambio en x: 1.046149  cambio en y: -0.005168
# 83 	 x: 21.528478  y: 0.122840  cambio en x: 1.048485  cambio en y: -0.005680
# 84 	 x: 20.477403  y: 0.129114  cambio en x: 1.051075  cambio en y: -0.006274
# 85 	 x: 19.423439  y: 0.136082  cambio en x: 1.053964  cambio en y: -0.006968
# 86 	 x: 18.366230  y: 0.143867  cambio en x: 1.057208  cambio en y: -0.007785
# 87 	 x: 17.305352  y: 0.152625  cambio en x: 1.060878  cambio en y: -0.008758
# 88 	 x: 16.240289  y: 0.162556  cambio en x: 1.065064  cambio en y: -0.009930
# 89 	 x: 15.170404  y: 0.173916  cambio en x: 1.069885  cambio en y: -0.011360
# 90 	 x: 14.094904  y: 0.187048  cambio en x: 1.075499  cambio en y: -0.013131
# 91 	 x: 13.012782  y: 0.202411  cambio en x: 1.082123  cambio en y: -0.015363
# 92 	 x: 11.922728  y: 0.220645  cambio en x: 1.090053  cambio en y: -0.018234
# 93 	 x: 10.823015  y: 0.242665  cambio en x: 1.099713  cambio en y: -0.022020
# 94 	 x: 9.711304  y: 0.269831  cambio en x: 1.111711  cambio en y: -0.027166
# 95 	 x: 8.584376  y: 0.304259  cambio en x: 1.126928  cambio en y: -0.034427
# 96 	 x: 7.437748  y: 0.349430  cambio en x: 1.146629  cambio en y: -0.045171
# 97 	 x: 6.265206  y: 0.411506  cambio en x: 1.172542  cambio en y: -0.062077
# 98 	 x: 5.058477  y: 0.502453  cambio en x: 1.206729  cambio en y: -0.090946
# 99 	 x: 3.807492  y: 0.648630  cambio en x: 1.250985  cambio en y: -0.146177
# 100 	 x: 2.499251  y: 0.920481  cambio en x: 1.308241  cambio en y: -0.271851
# 101 	 x: 1.066509  y: 1.597106  cambio en x: 1.432742  cambio en y: -0.676624
# 102 	 x: -3.411519  y: 9.374999  cambio en x: 4.478028  cambio en y: -7.777893
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9ce6f5e52987> in <module>()
#      17
#      18     # Función 1  ln(xy) + x^2 y^2 - 8 = 0
# ---> 19     f1 = m.log(x*y)+(x**2)*(y**2)-8
#      20     #Función 2 sen(x) + y e^x - 2 = 0
#      21     f2 = m.sin(mpmath.radians(x)) +y*m.exp(x) -2
#
# ValueError: math domain error

# %%
X = Symbol('X')
Y = Symbol('Y')
funcs1 = ln(X*Y) + X**2 * Y**2 -8
funcs2 = sin(X) + Y * exp(X)
vis = [100,100]
MN_NRM([funcs1,funcs2],vis,[X,Y])
# Out:
# 2*X*Y**2 + 1/X
# 2*X**2*Y + 1/Y
# Y*exp(X) + cos(X)
# exp(X)
# 1 	 x: 99.494949  y: 50.505050
# 2 	 x: 98.989873  y: 25.508909
# 3 	 x: 98.484770  y: 12.884617
# 4 	 x: 97.979641  y: 6.508399
# 5 	 x: 97.474483  y: 3.287772
# 6 	 x: 96.969287  y: 1.660970
# 7 	 x: 96.464010  y: 0.839249
# 8 	 x: 95.958456  y: 0.424286
# 9 	 x: 95.451730  y: 0.214997
# 10 	 x: 94.939871  y: 0.110048
# 80 	 x: 24.667144  y: 0.107268
# 81 	 x: 23.623112  y: 0.111992
# 82 	 x: 22.576963  y: 0.117160
# 83 	 x: 21.528478  y: 0.122840
# 84 	 x: 20.477403  y: 0.129114
# 85 	 x: 19.423439  y: 0.136082
# 86 	 x: 18.366230  y: 0.143867
# 87 	 x: 17.305352  y: 0.152625
# 88 	 x: 16.240288  y: 0.162556
# 89 	 x: 15.170401  y: 0.173916
# 90 	 x: 14.094895  y: 0.187048
# 91 	 x: 13.012756  y: 0.202411
# 92 	 x: 11.922675  y: 0.220646
# 93 	 x: 10.822915  y: 0.242667
# 94 	 x: 9.711011  y: 0.269838
# 95 	 x: 8.583138  y: 0.304295
# 96 	 x: 7.433329  y: 0.349598
# 97 	 x: 6.253798  y: 0.412107
# 98 	 x: 5.036121  y: 0.504210
# 99 	 x: 3.754466  y: 0.655034
# 100 	 x: 2.250002  y: 0.970130
# 101 	 x: -0.453985  y: 2.362182
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d2bcf600c4f3> in <module>()
#       4 funcs2 = sin(X) + Y * exp(X)
#       5 vis = [100,100]
# ----> 6 MN_NRM([funcs1,funcs2],vis,[X,Y])
#
# D:\GitHub\NRMLAB\MetNums\MetNum.py in MN_NRM(funciones, vec, variables)
#     164         for i in range(LF):
#     165             #evaluar funciones
# --> 166             funceval[i]=funciones[i].evalf(subs=d)
#     167             for j,je in enumerate(variables):
#     168                 #Evaluar las derivadas
#
# C:\Users\mario\Anaconda3\envs\cap\lib\site-packages\sympy\core\expr.py in __float__(self)
#     347             return float(result)
#     348         if result.is_number and result.as_real_imag()[1]:
# --> 349             raise TypeError("can't convert complex to float")
#     350         raise TypeError("can't convert expression to float")
#     351
#
# TypeError: can't convert complex to float

# %%
jac_inv

# %%
m_i = np.linalg.inv([[df1dx,df1dy], [df2dx,df2dy]])
m_i

# %%
jac_inv.dot([-f1,-f2])

# %%
[[df1dx,df1dy], [df2dx,df2dy]]

# %%
jac_inv.dot([[-f1],[-f2]])

# %%
np.dot(jac_inv,[[-f1],[-f2]])

# %%
np.dot([[-f1],[-f2]],jac_inv)

# %%
np.dot([-f1-f2],jac_inv)

# %%
np.array([(-f1)*m_i[0,0]+(-f1)*m_i[1,0],(-f2)*m_i[0,1]+(-f2)*m_i[1,1]])

# %%
np.array([(-f1)*m_i[0,0]+(-f2)*m_i[0,1],(-f1)*m_i[1,0]+(-f2)*m_i[1,1]])

# %%
h

# %%
jac_inv.dot([-f1,-f2])

# %% [markdown]
# #### Ejercicio 4:
# Utilizando los valores iniciales x = 1.2, y = 1.2 se usa el método de punto fijo multivariable
#
# <center> $y=-x^2+x+0.75$ </center>
# <center> $y+5xy=x^2$ </center

# %%
#Valores iniciales
X0 = 1.2
Y0 = 1.2

fin = 1
gxs = []
gys = [] 
print('X0: ', X0, 'Y0: ', Y0)
cont = 0

while fin == 1:
    cont += 1
    
    #Se guardan los valores de la iteración anterior
    x_anterior = X0
    y_anterior = Y0
#     X0 = X0**2+Y0-0.75
#     Y0 = X0**2-(5*X0*Y0)
#     X0 = np.sqrt(Y0+5*X0*Y0)
#     Y0 = -X0**2+X0+0.75
#     Y0 = X0**2-5*X0*Y0
#     X0 = np.sqrt(X0+0.75-Y0)
#     Y0 = (X0**2-Y0)/(5*X0)
#     X0 = np.sqrt(X0+0.75-Y0)
    # Se evaluan los valores en los despejes realizados 
    # x = (x^2 - y)/5y
    X0 = (X0**2-Y0)/(5*Y0)
    # y = -x^2 + x + 0.75
    Y0 = -X0**2+X0+0.75
    
    print('It: {}'.format(cont),' X0: {0:.6f}'.format(X0), ' Y0: {0:.6f}'.format(Y0))
    
    # Comparamos la iteración anterior con la actual para medir el cambio
    resx = x_anterior - X0
    resy = y_anterior - Y0
    gxs.append(X0)
    gys.append(Y0)
    
    # Si el cambio es lo suficientemente bajo se detiene el proceso
    if -0.00000001 < resx < 0.00000001 and -0.00000001 < resy < 0.00000001:
        fin =0

allres = { 'X': gxs,
           'Y': gys}



allresdf = pd.DataFrame(allres)
allresdf
# Out:
# X0:  1.2 Y0:  1.2
# It: 1  X0: 0.040000  Y0: 0.788400
# It: 2  X0: -0.199594  Y0: 0.510568
# It: 3  X0: -0.184395  Y0: 0.531604
# It: 4  X0: -0.187208  Y0: 0.527745
# It: 5  X0: -0.186718  Y0: 0.528418
# It: 6  X0: -0.186804  Y0: 0.528300
# It: 7  X0: -0.186789  Y0: 0.528320
# It: 8  X0: -0.186792  Y0: 0.528317
# It: 9  X0: -0.186792  Y0: 0.528317
# It: 10  X0: -0.186792  Y0: 0.528317
# It: 11  X0: -0.186792  Y0: 0.528317
# It: 12  X0: -0.186792  Y0: 0.528317
#            X         Y
# 0   0.040000  0.788400
# 1  -0.199594  0.510568
# 2  -0.184395  0.531604
# 3  -0.187208  0.527745
# 4  -0.186718  0.528418
# 5  -0.186804  0.528300
# 6  -0.186789  0.528320
# 7  -0.186792  0.528317
# 8  -0.186792  0.528317
# 9  -0.186792  0.528317
# 10 -0.186792  0.528317
# 11 -0.186792  0.528317

# %%
X = Symbol('X')
Y = Symbol('Y')
desp1 = (X**2-Y)/(5*Y)
desp2 = -X**2+X+0.75
vis = [100,100]
MN_PFM([desp1,desp2],vis,[X,Y])
# Out:
#                        X                  Y
# 0       19.8000000000000  -371.490000000000
# 1     -0.411063554873617  0.169963198981048
# 2   -0.00116490256908256  0.748833740432922
# 3     -0.199999637570285  0.510000507401470
# 4     -0.184313797948143  0.531714625937788
# 5     -0.187221876376203  0.527726092629970
# 6     -0.186715824181010  0.528421376819397
# 7     -0.186804924808517  0.528298995258767
# 8     -0.186789268862560  0.528320500175230
# 9     -0.186792020771241  0.528316720204955
# 10    -0.186791537087727  0.528317384584677
# 11    -0.186791622102300  0.528317267810092
# 12    -0.186791607159753  0.528317288334923
# 13    -0.186791609786124  0.528317284727385
# 14    -0.186791609324501  0.528317285361462
# 15    -0.186791609405638  0.528317285250014
# 16    -0.186791609391377  0.528317285269603
# 17    -0.186791609393883  0.528317285266160
# 18    -0.186791609393443  0.528317285266765
